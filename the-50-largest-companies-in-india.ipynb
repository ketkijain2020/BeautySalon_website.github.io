# %% [markdown]
# <a href="https://www.kaggle.com/code/ketkijain/the-50-largest-companies-in-india?scriptVersionId=183636171" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-50-indian-companies/Top Company.csv

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_India'
data = pd.read_html(url)

# %%
data
# Out:
# [    Rank                                Name            Industry  \
#  0      1                 Reliance Industries        Conglomerate
#  1      2              Indian Oil Corporation         Oil and gas
#  2      3          Life Insurance Corporation             Banking
#  3      4     Oil and Natural Gas Corporation         Oil and gas
#  4      5                    Bharat Petroleum         Oil and gas
#  5      6                 State Bank of India             Banking
#  6      4                           HDFC Bank             Banking
#  7      5                          ICICI Bank             Banking
#  8      7                                HDFC          Financials
#  9      9           Tata Consultancy Services            Infotech
#  10    10                          Tata Steel      Iron and steel
#  11    11                           Axis Bank             Banking
#  12    12                        NTPC Limited           Utilities
# ...

# %%
comp=data[1]

# %%
comp
# Out:
#     Rank                                    Name            Industry  \
# 0      1                  Indian Oil Corporation         Oil and gas
# 1      2             Reliance Industries Limited         Oil and gas
# 2      3         Oil and Natural Gas Corporation         Oil and gas
# 3      4                     State Bank of India             Banking
# 4      5                             Tata Motors          Automotive
# 5      6                        Bharat Petroleum         Oil and gas
# 6      7                     Hindustan Petroleum         Oil and gas
# 7      8                          Rajesh Exports  Gems and jewellery
# 8      9                              Tata Steel      Iron and steel
# 9     10                              Coal India   Metals and mining
# 10    11               Tata Consultancy Services            Infotech
# 11    12                         Larsen & Toubro       Capital goods
# 12    13                     Hindalco Industries   Metals and mining
# ...

# %%
comp.head()
# Out:
#    Rank                             Name     Industry  Revenue (in ₹ Crore)  \
# 0     1           Indian Oil Corporation  Oil and gas                424321
# 1     2      Reliance Industries Limited  Oil and gas                410295
# 2     3  Oil and Natural Gas Corporation  Oil and gas                333143
# 3     4              State Bank of India      Banking                306528
# 4     5                      Tata Motors   Automotive                301175
#
#   Revenue growth Profits (in ₹ Crore) Headquarters State Controlled
# 0          13.2%                22189    New Delhi              Yes
# 1          28.2%                36075       Mumbai              NaN
# 2          11.0%                22106    New Delhi              Yes
# 3           2.6%               −4,556       Mumbai              Yes
# 4           7.9%                 8989       Mumbai              NaN

# %%
comp.tail()
# Out:
#     Rank                             Name     Industry  Revenue (in ₹ Crore)  \
# 45    46                    Tech Mahindra     Infotech                 32190
# 46    47                 UltraTech Cement       Cement                 32106
# 47    48                     Petronet LNG  Oil and gas                 30949
# 48    49  Power Grid Corporation of India    Utilities                 30908
# 49    50                    Bajaj Finserv   Financials                 30599
#
#    Revenue growth Profits (in ₹ Crore) Headquarters State Controlled
# 45           7.6%                 3800         Pune              NaN
# 46          23.7%                 2222       Mumbai              NaN
# 47          23.9%                 2110    New Delhi              Yes
# 48          16.1%                 8198      Gurgaon              Yes
# 49          24.9%                 2741         Pune              NaN

# %%
company = comp.to_csv('Top Company.csv',index=False)

# %% [markdown]
# Import the Scraped Dataset

# %%
df = pd.read_csv('/kaggle/working/Top Company.csv')

# %%
df
# Out:
#     Rank                                    Name            Industry  \
# 0      1                  Indian Oil Corporation         Oil and gas
# 1      2             Reliance Industries Limited         Oil and gas
# 2      3         Oil and Natural Gas Corporation         Oil and gas
# 3      4                     State Bank of India             Banking
# 4      5                             Tata Motors          Automotive
# 5      6                        Bharat Petroleum         Oil and gas
# 6      7                     Hindustan Petroleum         Oil and gas
# 7      8                          Rajesh Exports  Gems and jewellery
# 8      9                              Tata Steel      Iron and steel
# 9     10                              Coal India   Metals and mining
# 10    11               Tata Consultancy Services            Infotech
# 11    12                         Larsen & Toubro       Capital goods
# 12    13                     Hindalco Industries   Metals and mining
# ...

# %%
df.dtypes
# Out:
# Rank                     int64
# Name                    object
# Industry                object
# Revenue (in ₹ Crore)     int64
# Revenue growth          object
# Profits (in ₹ Crore)    object
# Headquarters            object
# State Controlled        object
# dtype: object

# %%
df.rename(columns={'Revenue growth':'Revenue growth(in %)'},inplace=True)

# %%
df
# Out:
#     Rank                                    Name            Industry  \
# 0      1                  Indian Oil Corporation         Oil and gas
# 1      2             Reliance Industries Limited         Oil and gas
# 2      3         Oil and Natural Gas Corporation         Oil and gas
# 3      4                     State Bank of India             Banking
# 4      5                             Tata Motors          Automotive
# 5      6                        Bharat Petroleum         Oil and gas
# 6      7                     Hindustan Petroleum         Oil and gas
# 7      8                          Rajesh Exports  Gems and jewellery
# 8      9                              Tata Steel      Iron and steel
# 9     10                              Coal India   Metals and mining
# 10    11               Tata Consultancy Services            Infotech
# 11    12                         Larsen & Toubro       Capital goods
# 12    13                     Hindalco Industries   Metals and mining
# ...

# %%
df['Revenue growth(in %)'] = df['Revenue growth(in %)'].str.rstrip('%').astype(float)

# %%
df
# Out:
#     Rank                                    Name            Industry  \
# 0      1                  Indian Oil Corporation         Oil and gas
# 1      2             Reliance Industries Limited         Oil and gas
# 2      3         Oil and Natural Gas Corporation         Oil and gas
# 3      4                     State Bank of India             Banking
# 4      5                             Tata Motors          Automotive
# 5      6                        Bharat Petroleum         Oil and gas
# 6      7                     Hindustan Petroleum         Oil and gas
# 7      8                          Rajesh Exports  Gems and jewellery
# 8      9                              Tata Steel      Iron and steel
# 9     10                              Coal India   Metals and mining
# 10    11               Tata Consultancy Services            Infotech
# 11    12                         Larsen & Toubro       Capital goods
# 12    13                     Hindalco Industries   Metals and mining
# ...

# %%
df.dtypes
# Out:
# Rank                      int64
# Name                     object
# Industry                 object
# Revenue (in ₹ Crore)      int64
# Revenue growth(in %)    float64
# Profits (in ₹ Crore)     object
# Headquarters             object
# State Controlled         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                     0
# Name                     0
# Industry                 0
# Revenue (in ₹ Crore)     0
# Revenue growth(in %)     0
# Profits (in ₹ Crore)     0
# Headquarters             0
# State Controlled        30
# dtype: int64

# %%
df
# Out:
#     Rank                                    Name            Industry  \
# 0      1                  Indian Oil Corporation         Oil and gas
# 1      2             Reliance Industries Limited         Oil and gas
# 2      3         Oil and Natural Gas Corporation         Oil and gas
# 3      4                     State Bank of India             Banking
# 4      5                             Tata Motors          Automotive
# 5      6                        Bharat Petroleum         Oil and gas
# 6      7                     Hindustan Petroleum         Oil and gas
# 7      8                          Rajesh Exports  Gems and jewellery
# 8      9                              Tata Steel      Iron and steel
# 9     10                              Coal India   Metals and mining
# 10    11               Tata Consultancy Services            Infotech
# 11    12                         Larsen & Toubro       Capital goods
# 12    13                     Hindalco Industries   Metals and mining
# ...

# %%
df.describe()
# Out:
#            Rank  Revenue (in ₹ Crore)  Revenue growth(in %)
# count  50.00000             50.000000             50.000000
# mean   25.50000         103652.620000             14.180000
# std    14.57738          98310.696233             11.101719
# min     1.00000          30599.000000              0.400000
# 25%    13.25000          43705.750000              5.550000
# 50%    25.50000          58051.500000             12.850000
# 75%    37.75000         120063.250000             19.725000
# max    50.00000         424321.000000             54.900000

# %%
df.describe(include='object')
# Out:
#                           Name     Industry Profits (in ₹ Crore) Headquarters  \
# count                       50           50                   50           50
# unique                      50           15                   50           11
# top     Indian Oil Corporation  Oil and gas                22189       Mumbai
# freq                         1           10                    1           25
#
#        State Controlled
# count                20
# unique                1
# top                 Yes
# freq                 20

# %%
df.Industry.value_counts()
# Out:
# Industry
# Oil and gas           10
# Banking               10
# Automotive             5
# Infotech               5
# Iron and steel         3
# Metals and mining      3
# Utilities              3
# Telecommunication      2
# Financials             2
# Consumer goods         2
# Gems and jewellery     1
# Capital goods          1
# Diversified            1
# Insurance              1
# Cement                 1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"]=[7.50,7]
plt.rcParams["figure.autolayout"]=True
df.hist()
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Industry', 'Revenue (in ₹ Crore)',
#        'Revenue growth(in %)', 'Profits (in ₹ Crore)', 'Headquarters',
#        'State Controlled'],
#       dtype='object')

# %%
plt.boxplot(df["Revenue (in ₹ Crore)"])
plt.grid()
plt.title('Revenue (in ₹ Crore)')
plt.plot()
# Out:
# []

# %%
df[df["Revenue (in ₹ Crore)"]==30599]
# Out:
#     Rank           Name    Industry  Revenue (in ₹ Crore)  \
# 49    50  Bajaj Finserv  Financials                 30599
#
#     Revenue growth(in %) Profits (in ₹ Crore) Headquarters State Controlled
# 49                  24.9                 2741         Pune              NaN

# %%
df[df["Revenue (in ₹ Crore)"]>200000]
# Out:
#    Rank                             Name     Industry  Revenue (in ₹ Crore)  \
# 0     1           Indian Oil Corporation  Oil and gas                424321
# 1     2      Reliance Industries Limited  Oil and gas                410295
# 2     3  Oil and Natural Gas Corporation  Oil and gas                333143
# 3     4              State Bank of India      Banking                306528
# 4     5                      Tata Motors   Automotive                301175
# 5     6                 Bharat Petroleum  Oil and gas                238638
# 6     7              Hindustan Petroleum  Oil and gas                221693
#
#    Revenue growth(in %) Profits (in ₹ Crore) Headquarters State Controlled
# 0                  13.2                22189    New Delhi              Yes
# 1                  28.2                36075       Mumbai              NaN
# 2                  11.0                22106    New Delhi              Yes
# ...

# %%
plt.violinplot(df["Revenue (in ₹ Crore)"])
plt.grid()
plt.title('Revenue (in ₹ Crore)',color='r')
plt.plot()
# Out:
# []

# %%
df.Industry.value_counts().plot(kind='bar',color='pink')
plt.title('Industry Name')
plt.show()

# %%
df.Headquarters.value_counts().plot(kind='bar',color='yellow')
plt.title('Headquarters Name')
plt.show()
